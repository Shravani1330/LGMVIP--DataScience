# %% [markdown]
# <a href="https://colab.research.google.com/github/Upadhyayshravani/LGMVIP--DataScience/blob/main/Image_To_PencilSketch_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LGM VIP-DATA SCIENCE(JAN 2023)**
#
# **NAME- SHRAVANI UPADHYAY**
#
# **BEGINNER LEVEL TASK**
#
# **TASK 3**- **IMAGE TO PENCIL SKETCH WITH PYTHON**
#
# **Image** - LGM TASK3.jpg

# %% [markdown]
# **IMPORTING LIBRARIES**

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# Uploading the image

# %%
from google.colab import drive
drive.mount('/content/gdrive')

image=cv2.imread("/content/gdrive/MyDrive/Colab Notebooks/LGM TASK3.jpg")
original_image =cv2.resize(image, (700, 500))
cv2_imshow(original_image)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# <PIL.Image.Image image mode=RGB size=700x500 at 0x7F74B89A1B50>

# %% [markdown]
# ## **Convert the RBG image to grayscale image**

# %%
gray_scale_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F74B89A1AC0>

# %% [markdown]
# ## **Inverted the grayscale image**

# %%
inverted_gray_scale_image = cv2.bitwise_not(gray_scale_image)
cv2_imshow(inverted_gray_scale_image)
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F74B8936FA0>

# %% [markdown]
# ## **Applying Guassian Blur**

# %%
inverted_blurry_image = cv2.GaussianBlur(inverted_gray_scale_image, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(inverted_blurry_image)
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F74B8936EB0>

# %% [markdown]
# ## **Mixing the Gray scale image with Inverted blurry image**

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
final_pencil_sketch_image = dodgeV2(gray_scale_image,inverted_blurry_image)

cv2_imshow(final_pencil_sketch_image )
# Out:
# <PIL.Image.Image image mode=L size=700x500 at 0x7F74B8936790>

# %% [markdown]
# # **Original image and pencil sketch image**

# %%
cv2_imshow(original_image)

cv2_imshow(final_pencil_sketch_image)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500 at 0x7F74C65D2520>
# <PIL.Image.Image image mode=L size=700x500 at 0x7F74B8936850>
